# %% [markdown]
# # Task 2
# ## Titanic - Machine Learning from Disaster

# %% [markdown]
# # Importing datas

# %% [markdown]
# # There 3 Tables Named as df,df1.df2

# %%
import pandas as pd
data = pd.read_csv("C:/Users/srcha/OneDrive/Desktop/titanic/gender_submission.csv")
df= pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
data1 = pd.read_csv("C:/Users/srcha/OneDrive/Desktop/titanic/test.csv")
df1=pd.DataFrame(data1)
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data2=pd.read_csv("C:/Users/srcha/OneDrive/Desktop/titanic/train.csv")
df2= pd.DataFrame(data2)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Shape of the tables df,df1,df2

# %%
print(f'Gender submission shape:',df.shape)
print(f'Test table shape:',df1.shape)
print(f'train table shape:',df2.shape)
# Out:
# Gender submission shape: (418, 2)
# Test table shape: (418, 11)
# train table shape: (891, 12)

# %% [markdown]
# # Joined table 1 and Table 2 and named it as df3

# %%
df3= pd.merge(df,df1,on='PassengerId',how='inner')
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Table column and its informations
# * Now table 1 and Table2 joined and named as df3 and Tabl 3 is df2

# %%
#Table 1 and Table 2
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       296 non-null    float64
#  9   Fare         418 non-null    float64
#  10  Cabin        418 non-null    object
#  11  Embarked     418 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 39.3+ KB

# %%
#Table 3
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Checking null values in each column

# %%
df3.isnull().sum() #Table 1 and 2
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2.isnull().sum()  #Table 3
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Summarization of Datas

# %%
df3.describe(include='all') #Table 1 and Table 2
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %%
df2.describe(include='all') #Table 3
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ## Displaying the first five rows

# %%
df2.head() #Displaying the first 5 rows of Table 3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3.head() #Displaying the fist 5 rows of table 1 and table 2
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Displaying last 5 rows

# %%
df2.tail() #Displaying the last 5 rows of table 3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df3.tail()  #Displaying the last 5 rows of table 1 and table 2
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # The Age,Fare and Cabin Null values hase been treated

# %% [markdown]
# ## This is for Table 3

# %%
df2.isnull().sum() #Checking null values in Table 3
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2['Age']=df2['Age'].fillna(28) # Replacing null values in age column at table 3

# %%
df2['Cabin']=df2["Cabin"].fillna("unknown") # Replacing null values in cabin column at table 3

# %%
df2['Embarked']=df2['Embarked'].fillna('unknown') # Replacing null values in embaked column at table 3

# %%
df2.isnull().sum() # After replacing Checking null values in Table 3
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df2.head() #Displaying The First 5 rows of Table 3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  unknown        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  unknown        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
df2.tail() #Displaying The last 5 rows of Table 3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex      Age  SibSp  Parch      Ticket   Fare    Cabin Embarked
# 886    male     27.0      0      0      211536  13.00  unknown        S
# 887  female     19.0      0      0      112053  30.00      B42        S
# 888  female  unknown      1      2  W./C. 6607  23.45  unknown        S
# 889    male     26.0      0      0      111369  30.00     C148        C
# 890    male     32.0      0      0      370376   7.75  unknown        Q

# %% [markdown]
# ##  This is for combined Table

# %%
df3.isnull().sum() #Checking Null values for Table 1 and Table 2
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df3['Age']=df3['Age'].fillna(27) #age NAN is been replaced by 27 because it is  median for table 1 and 2

# %%
df3['Fare']=df3['Fare'].fillna(14.4) #Fare NAN is replaced by 14.4 because it is median for table 1 and 2

# %%
df3['Cabin']=df3['Cabin'].fillna('unknown') #cabin NAN replaced by unknown for table 1 and 2

# %%
df3.isnull().sum() #Displaying The first 5 rows of Table 3
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df3.head() #Displaying The first 5 rows of Table 3
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare    Cabin Embarked
# 0   330911   7.8292  unknown        Q
# 1   363272   7.0000  unknown        S
# 2   240276   9.6875  unknown        Q
# 3   315154   8.6625  unknown        S
# 4  3101298  12.2875  unknown        S

# %%
df3.tail() #Displaying The last 5 rows of Table 3
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare    Cabin Embarked
# 413  28.0      0      0           A.5. 3236    8.0500  unknown        S
# 414  39.0      0      0            PC 17758  108.9000     C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500  unknown        S
# 416  28.0      0      0              359309    8.0500  unknown        S
# 417  28.0      1      1                2668   22.3583  unknown        C

# %% [markdown]
# # Filtering the passenger age 25 and above , Male

# %%
df_filter = df3[(df3['Age']>25) & (df3['Sex']=='male')] #Displaying for age 25 and above and male,Table 1 and 2
df_filter.head()
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0           892         0       3              Kelly, Mr. James  male  34.5
# 2           894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3           895         0       3              Wirz, Mr. Albert  male  27.0
# 7           899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# 10          902         0       3              Ilieff, Mr. Ylio  male  28.0
#
#     SibSp  Parch  Ticket     Fare    Cabin Embarked
# 0       0      0  330911   7.8292  unknown        Q
# 2       0      0  240276   9.6875  unknown        Q
# 3       0      0  315154   8.6625  unknown        S
# 7       1      1  248738  29.0000  unknown        S
# 10      0      0  349220   7.8958  unknown        S

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df2['Age']=pd.to_numeric(df2['Age'],errors='coerce') #Age is changed to numeric

# %%
df_filter1=df2[(df2['Age']>25)& (df2['Sex']=='male')]  #Displaying for age 25 and above and male,Table 3
df_filter1.head()
# Out:
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4             5         0       3     Allen, Mr. William Henry  male  35.0
# 6             7         0       1      McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2         Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2        Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch    Ticket     Fare    Cabin Embarked
# 4       0      0  373450.0   8.0500  unknown        S
# 6       0      0   17463.0  51.8625      E46        S
# 13      1      5  347082.0  31.2750  unknown        S
# 20      0      0  239865.0  26.0000  unknown        S
# 21      0      0  248698.0  13.0000      D56        S

# %% [markdown]
# # I have changed the ticket price column object to float

# %%
df2['Ticket']=pd.to_numeric(df2['Ticket'],errors='coerce')

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df3['Ticket']=pd.to_numeric(df3['Ticket'],errors='coerce')

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Filtering the passenger Ticket above 200000

# %%
df_filter1= df3[(df3['Ticket']>200000)] #Table 1 and 2
df_filter1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#       Ticket     Fare    Cabin Embarked
# 0   330911.0   7.8292  unknown        Q
# 1   363272.0   7.0000  unknown        S
# 2   240276.0   9.6875  unknown        Q
# 3   315154.0   8.6625  unknown        S
# 4  3101298.0  12.2875  unknown        S

# %%
df_filter2= df2[(df2['Ticket']>2000)] #Table 3
df_filter2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                            Name     Sex      Age  SibSp  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.0      1
# 4                      Allen, Mr. William Henry    male     35.0      0
# 5                              Moran, Mr. James    male  unknown      0
# 6                       McCarthy, Mr. Timothy J    male     54.0      0
# 7                Palsson, Master. Gosta Leonard    male      2.0      3
#
#    Parch    Ticket     Fare    Cabin Embarked
# 3      0  113803.0  53.1000     C123        S
# 4      0  373450.0   8.0500  unknown        S
# 5      0  330877.0   8.4583  unknown        Q
# 6      0   17463.0  51.8625      E46        S
# 7      1  349909.0  21.0750  unknown        S

# %% [markdown]
# # Cabin types and its count

# %%
df2['Cabin'].value_counts() #Table 3
# Out:
# Cabin
# unknown        687
# C23 C25 C27      4
# G6               4
# B96 B98          4
# C22 C26          3
#               ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
# Name: count, Length: 148, dtype: int64

# %%
df3['Cabin'].value_counts() #Table 1 and 2
# Out:
# Cabin
# unknown            327
# B57 B59 B63 B66      3
# C89                  2
# C116                 2
# C80                  2
#                   ...
# E45                  1
# E52                  1
# B58 B60              1
# C62 C64              1
# C105                 1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# # Gender count

# %%
df3['Sex'].value_counts() #Table 1 and 2
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
df2['Sex'].value_counts() #Table 3
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# # Sorting the Ticket Price

# %% [markdown]
# # By Ascending Order

# %%
sorted_1 = df3.sort_values('Ticket') #Table 1 and 2
sorted_1.head()
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 378         1270         0       1    Hipkins, Mr. William Edward  male  55.0
# 11           903         0       1     Jones, Mr. Charles Cresson  male  46.0
# 357         1249         0       3            Lockyer, Mr. Edward  male  28.0
# 39           931         0       3                  Hee, Mr. Ling  male  28.0
# 328         1220         0       2  Clarke, Mr. Charles Valentine  male  29.0
#
#      SibSp  Parch  Ticket     Fare    Cabin Embarked
# 378      0      0   680.0  50.0000      C39        S
# 11       0      0   694.0  26.0000  unknown        S
# 357      0      0  1222.0   7.8792  unknown        S
# 39       0      0  1601.0  56.4958  unknown        S
# 328      1      0  2003.0  26.0000  unknown        S

# %%
sorted_2 = df2.sort_values('Ticket') #Table 3
sorted_2.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
#
#      Parch  Ticket   Fare Cabin Embarked
# 504      0  110152  86.50   B79        S
# 257      0  110152  86.50   B77        S
# 759      0  110152  86.50   B77        S
# 262      1  110413  79.65   E67        S
# 558      1  110413  79.65   E67        S

# %% [markdown]
# # By Descending order

# %%
sorted_2 = df3.sort_values('Ticket',ascending=False) #Table 1 and 2
sorted_2.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 72           964         1       3
# 367         1259         1       3
# 232         1124         0       3
# 123         1015         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 72                 Nieminen, Miss. Manta Josefina  female  29.0      0      0
# 367  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0      0
# 232                       Wiklund, Mr. Karl Johan    male  21.0      1      0
# 123                       Carver, Mr. Alfred John    male  28.0      0      0
#
#         Ticket     Fare    Cabin Embarked
# 4    3101298.0  12.2875  unknown        S
# 72   3101297.0   7.9250  unknown        S
# 367  3101295.0  39.6875  unknown        S
# 232  3101266.0   6.4958  unknown        S
# 123   392095.0   7.2500  unknown        S

# %% [markdown]
# # Sorting Columns

# %%
sorted_columns = df3.sort_index(axis=1)
sorted_columns
# Out:
#       Age    Cabin Embarked      Fare  \
# 0    34.5  unknown        Q    7.8292
# 1    47.0  unknown        S    7.0000
# 2    62.0  unknown        Q    9.6875
# 3    27.0  unknown        S    8.6625
# 4    22.0  unknown        S   12.2875
# ..    ...      ...      ...       ...
# 413  28.0  unknown        S    8.0500
# 414  39.0     C105        C  108.9000
# 415  38.5  unknown        S    7.2500
# 416  28.0  unknown        S    8.0500
# 417  28.0  unknown        C   22.3583
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James      0          892       3
# 1                Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 2                       Myles, Mr. Thomas Francis      0          894       2
# 3                                Wirz, Mr. Albert      0          895       3
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1          896       3
# ...

# %% [markdown]
# # Exporting the Datas

# %%
df_filter1.to_csv('Ticket.csv',index=False) #Table 1 and 2

# %%
df_filter2.to_csv('Ticket1.csv',index=False) #Table 3
